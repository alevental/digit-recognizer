# %% [markdown]
# #Digit Recognizer
# Experimentation notebook for the [Digit Recognizer](https://www.kaggle.com/c/digit-recognizer) competition on Kaggle

# %%
# %pylab inline
import pandas as pd
from sklearn import neighbors
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/aleksander/anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from /Users/aleksander/anaconda/python.app/Contents/lib/python2.7/argparse.pyc, but /Users/aleksander/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
train_data = pd.read_csv(r'data/train.csv')

# %%
train_data.head()

ex = train_data.head()

num = train_data.values[7][1:].reshape(28,28)

for idx in range(15):
    img_data = train_data.values[idx][1:].reshape(28,28)
    num = train_data.values[idx][0]
    
    plt.subplot(3, 5, idx+1)
    plt.axis('off')
    plt.title('Training: %i' % num )
    plt.imshow(img_data, cmap=cm.Greys_r)

# %%
X = train_data.drop('label', 1).values
Y = train_data['label'].values

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors=10)
clf.fit(X,Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=10, p=2, weights='uniform')

# %%
X_test = pd.read_csv(r'data/test.csv').values

# %%
Y_test = clf.predict(X_test[:15])
Y_test
# Out:
# array([2, 0, 9, 4, 3, 7, 0, 3, 0, 3, 5, 7, 4, 0, 4])

# %%
for idx in range(15):
    img_data = X_test[idx].reshape(28,28)
    num = Y_test[idx]
    
    plt.subplot(3, 5, idx+1)
    plt.axis('off')
    plt.title('Predict: %i' % num )
    plt.imshow(img_data, cmap=cm.Greys_r)
